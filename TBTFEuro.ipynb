# %% [markdown]
# # Too Big to Fail Goes to the Euros 2024

# %%
import TBTFEuro
TBTF = TBTFEuro.TBTFEuro()

# %%
bois = TBTF.bois

# %% [markdown]
# ## Realiseret Gruppespil

# %%
TBTF._VisGrupperStilling()
# Out:
# <div style='display: grid; grid-template-columns: repeat(3, 1fr); gap: 15px;'><style type="text/css">
# #T_9cb1c_row0_col0, #T_9cb1c_row0_col1, #T_9cb1c_row0_col2, #T_9cb1c_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_9cb1c_row1_col0, #T_9cb1c_row1_col1, #T_9cb1c_row1_col2, #T_9cb1c_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# </style>
# <table id="T_9cb1c" style="display:inline;margin:5px;">
#   <caption>Gruppe A</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cb1c_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_9cb1c_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_9cb1c_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_9cb1c_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Bois' Bud på Gruppespillet

# %% [markdown]
# Værdier udenfor parenteser angiver bud, mens parenteser angiver forskel fra faktisk resultat. Parenteser ved hold angiver afstand fra faktisk placering.

# %%
for boi in bois:
    TBTF._VisGrupperStillingBoisDiff(boi)
# Out:
#         <style>
#             .bois-dataframe {
#                 font-size: 10px;
#             }
#             .bois-dataframe thead th {
#                 text-align: center;
#                 font-size: 12px;
#             }
#             .bois-dataframe tbody td {
#                 text-align: center;
#             }
#             .bois-dataframe thead th:nth-child(1), .bois-dataframe tbody td:nth-child(1) {
#                 width: 150px;
#             }
#             .bois-dataframe thead th:nth-child(2), .bois-dataframe tbody td:nth-child(2) {
#                 width: 100px;
#             }
#             .bois-dataframe thead th:nth-child(3), .bois-dataframe tbody td:nth-child(3) {
#                 width: 100px;
#             }
#             .bois-dataframe thead th:nth-child(4), .bois-dataframe tbody td:nth-child(4) {
#                 width: 100px;
#             }
#             .bois-dataframe thead th:nth-child(5), .bois-dataframe tbody td:nth-child(5) {
# ...

# %% [markdown]
# ## Bois' Fordelinger af Bud på Resultater

# %% [markdown]
# ## Bois' Point

# %% [markdown]
# Point nedenfor er inklusiv bonuspoint i gruppespil og slutspilspoint.

# %%
TBTF._VisBoisStilling()
# Out:
#         <div style="display: flex; justify-content: center;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Boi</th>
#       <th>Point</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Gustav</td>
#       <td>170</td>
#     </tr>
#     <tr>
#       <td>Rasmus</td>
#       <td>158</td>
#     </tr>
#     <tr>
#       <td>Jens</td>
#       <td>147</td>
#     </tr>
#     <tr>
#       <td>Findsen</td>
#       <td>133</td>
#     </tr>
#     <tr>
#       <td>Thomas</td>
#       <td>133</td>
#     </tr>
#     <tr>
#       <td>Mads</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <td>Kris</td>
#       <td>126</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
