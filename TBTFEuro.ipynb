# %%
import TBTFEuro as EURO

# %%
TBTF = EURO.TBTFEuro()
# Out:
# <div style='display: grid; grid-template-columns: repeat(3, 1fr); gap: 15px;'><style type="text/css">
# #T_5464f_row0_col0, #T_5464f_row0_col1, #T_5464f_row0_col2, #T_5464f_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_5464f_row1_col0, #T_5464f_row1_col1, #T_5464f_row1_col2, #T_5464f_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# </style>
# <table id="T_5464f" style="display:inline;margin:5px;">
#   <caption>Gruppe A</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5464f_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_5464f_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_5464f_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_5464f_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
