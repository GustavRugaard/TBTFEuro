# %% [markdown]
# # Too Big to Fail Goes to the Euros 2024

# %%
import TBTFEuro
bois = TBTFEuro.TBTFEuro()

# %% [markdown]
# ## Realiseret Gruppespil

# %%
bois._VisGrupperStilling()
# Out:
# <div style='display: grid; grid-template-columns: repeat(3, 1fr); gap: 15px;'><style type="text/css">
# #T_e1bb2_row0_col0, #T_e1bb2_row0_col1, #T_e1bb2_row0_col2, #T_e1bb2_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_e1bb2_row1_col0, #T_e1bb2_row1_col1, #T_e1bb2_row1_col2, #T_e1bb2_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# </style>
# <table id="T_e1bb2" style="display:inline;margin:5px;">
#   <caption>Gruppe A</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1bb2_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_e1bb2_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_e1bb2_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_e1bb2_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1bb2_level0_row0" class="row_heading level0 row0" >Tyskland</th>
#       <td id="T_e1bb2_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_e1bb2_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_e1bb2_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_e1bb2_row0_col3" class="data row0 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e1bb2_level0_row1" class="row_heading level0 row1" >Schweiz</th>
#       <td id="T_e1bb2_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_e1bb2_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_e1bb2_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_e1bb2_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e1bb2_level0_row2" class="row_heading level0 row2" >Ungarn</th>
#       <td id="T_e1bb2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e1bb2_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_e1bb2_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_e1bb2_row2_col3" class="data row2 col3" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_e1bb2_level0_row3" class="row_heading level0 row3" >Skotland</th>
#       <td id="T_e1bb2_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_e1bb2_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_e1bb2_row3_col2" class="data row3 col2" >7</td>
#       <td id="T_e1bb2_row3_col3" class="data row3 col3" >-5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f3535_row0_col0, #T_f3535_row0_col1, #T_f3535_row0_col2, #T_f3535_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_f3535_row1_col0, #T_f3535_row1_col1, #T_f3535_row1_col2, #T_f3535_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# </style>
# <table id="T_f3535" style="display:inline;margin:5px;">
#   <caption>Gruppe B</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3535_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_f3535_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_f3535_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_f3535_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3535_level0_row0" class="row_heading level0 row0" >Spanien</th>
#       <td id="T_f3535_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_f3535_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_f3535_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f3535_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f3535_level0_row1" class="row_heading level0 row1" >Italien</th>
#       <td id="T_f3535_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_f3535_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_f3535_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_f3535_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3535_level0_row2" class="row_heading level0 row2" >Kroatien</th>
#       <td id="T_f3535_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f3535_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_f3535_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_f3535_row2_col3" class="data row2 col3" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f3535_level0_row3" class="row_heading level0 row3" >Albanien</th>
#       <td id="T_f3535_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_f3535_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_f3535_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_f3535_row3_col3" class="data row3 col3" >-2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f19d0_row0_col0, #T_f19d0_row0_col1, #T_f19d0_row0_col2, #T_f19d0_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_f19d0_row1_col0, #T_f19d0_row1_col1, #T_f19d0_row1_col2, #T_f19d0_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# #T_f19d0_row2_col0, #T_f19d0_row2_col1, #T_f19d0_row2_col2, #T_f19d0_row2_col3 {
#   background-color: rgba(0, 209, 0, 0.12);
# }
# </style>
# <table id="T_f19d0" style="display:inline;margin:5px;">
#   <caption>Gruppe C</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f19d0_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_f19d0_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_f19d0_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_f19d0_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f19d0_level0_row0" class="row_heading level0 row0" >England</th>
#       <td id="T_f19d0_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_f19d0_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_f19d0_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_f19d0_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f19d0_level0_row1" class="row_heading level0 row1" >Danmark</th>
#       <td id="T_f19d0_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_f19d0_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_f19d0_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_f19d0_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f19d0_level0_row2" class="row_heading level0 row2" >Slovenien</th>
#       <td id="T_f19d0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f19d0_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_f19d0_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_f19d0_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f19d0_level0_row3" class="row_heading level0 row3" >Serbien</th>
#       <td id="T_f19d0_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_f19d0_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f19d0_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_f19d0_row3_col3" class="data row3 col3" >-1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c694e_row0_col0, #T_c694e_row0_col1, #T_c694e_row0_col2, #T_c694e_row0_col3 {
#   background-color: rgba(0, 209, 0, 0.5);
# }
# #T_c694e_row1_col0, #T_c694e_row1_col1, #T_c694e_row1_col2, #T_c694e_row1_col3 {
#   background-color: rgba(0, 209, 0, 0.25);
# }
# #T_c694e_row2_col0, #T_c694e_row2_col1, #T_c694e_row2_col2, #T_c694e_row2_col3 {
#   background-color: rgba(0, 209, 0, 0.12);
# }
# </style>
# <table id="T_c694e" style="display:inline;margin:5px;">
#   <caption>Gruppe D</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c694e_level0_col0" class="col_heading level0 col0" >Point</th>
#       <th id="T_c694e_level0_col1" class="col_heading level0 col1" >Mål for</th>
#       <th id="T_c694e_level0_col2" class="col_heading level0 col2" >Mål imod</th>
#       <th id="T_c694e_level0_col3" class="col_heading level0 col3" >Målforskel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c694e_level0_row0" class="row_heading level0 row0" >Østrig</th>
#       <td id="T_c694e_row0_col0" class="data row0 col0" >6</td>
#       <td id="T

# %% [markdown]
# ## Bois' Bud på Gruppespillet

# %% [markdown]
# ## Bois' Point for Gruppespillet

# %%
bois._VisBoisStilling()
# Out:
#         <div style="display: flex; justify-content: center;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Boi</th>
#       <th>Point</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Gustav</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <td>Rasmus</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <td>Jens</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <td>Findsen</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <td>Kris</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <td>Mads</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <td>Thomas</td>
#       <td>65</td>
#     </tr>
#   </tbody>
# </table>
#         </div>

# %% [markdown]
# ## Bois' Fordelinger af Bud på Resultater
